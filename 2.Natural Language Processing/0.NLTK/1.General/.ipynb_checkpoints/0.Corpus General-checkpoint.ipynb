# %% [markdown]
# # NLP: CORPORA
#
# Corpora is just a body of texts. Generally, corpora are grouped by some sort of defining characteristic. Most natural language toolkit's **(NLTK)** corpus readers include a variety of access methods such as _words()_ , _raw()_ , and _sents()_

# %% [markdown]
# <h4>Where is my nltk package installed </h4>

# %%
# Import the nltk package
import nltk
# Print the location of the nltk package
print(nltk.__file__)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/nltk/__init__.py

# %% [markdown]
# ### Reading one of the corpora: Gutenberg Project
#
# For the next part of the code we need to download the Gutenberg corpora
#
# In a terminal we type:
# * `import nltk`
# * `nltk.download()`
# * Choose the Gutneberg project in the corpora window and dowload it

# %% [markdown]
# ### Let's analyse the files in the Gutenberg Corpus

# %% [markdown]
# <h4>Average characters per word, words per sentence, sentence per file,...</h4>

# %%
from nltk.corpus import gutenberg
for f in nltk.corpus.gutenberg.fileids():
    num_char = len(gutenberg.raw(f))
    num_words = len(gutenberg.words(f))
    num_sents = len(gutenberg.sents(f))
    num_vocab = len(set(w.lower() for w in gutenberg.words(f))) # number of unique words
    print(round(num_char/num_words), round(num_words/num_sents), round(num_words/num_vocab), f)
# Out:
# 5 25 26 austen-emma.txt
# 5 26 17 austen-persuasion.txt
# 5 28 22 austen-sense.txt
# 4 34 79 bible-kjv.txt
# 5 19 5 blake-poems.txt
# 4 19 14 bryant-stories.txt
# 4 18 12 burgess-busterbrown.txt
# 4 20 13 carroll-alice.txt
# 5 20 12 chesterton-ball.txt
# 5 23 11 chesterton-brown.txt
# 5 18 11 chesterton-thursday.txt
# 4 21 25 edgeworth-parents.txt
# 5 26 15 melville-moby_dick.txt
# 5 52 11 milton-paradise.txt
# 4 12 9 shakespeare-caesar.txt
# 4 12 8 shakespeare-hamlet.txt
# 4 12 7 shakespeare-macbeth.txt
# 5 36 12 whitman-leaves.txt

# %% [markdown]
# ### Once a corpus is downloaded it can be used in the code:

# %%
# Once downloaded we can import the corpora 
from nltk.corpus import gutenberg
# We will also import the toknization tools for words and sentences
from nltk.tokenize import sent_tokenize , word_tokenize

sample = gutenberg.raw("bible-kjv.txt")
sentence = sent_tokenize(sample)

# Print the first sentence of the sample text
print(sentence[0:5])
# Out:
# ['[The King James Bible]\n\nThe Old Testament of the King James Bible\n\nThe First Book of Moses:  Called Genesis\n\n\n1:1 In the beginning God created the heaven and the earth.', '1:2 And the earth was without form, and void; and darkness was upon\nthe face of the deep.', 'And the Spirit of God moved upon the face of the\nwaters.', '1:3 And God said, Let there be light: and there was light.', '1:4 And God saw the light, that it was good: and God divided the light\nfrom the darkness.']

# %% [markdown]
# #### We can now tokenize each of the sentences using the word tokenizer

# %%
words = word_tokenize(sentence[0])
print(words[:])
# Out:
# ['[', 'The', 'King', 'James', 'Bible', ']', 'The', 'Old', 'Testament', 'of', 'the', 'King', 'James', 'Bible', 'The', 'First', 'Book', 'of', 'Moses', ':', 'Called', 'Genesis', '1:1', 'In', 'the', 'beginning', 'God', 'created', 'the', 'heaven', 'and', 'the', 'earth', '.']

# %% [markdown]
# ## Extra Material
#
# For the next part of this notebook we will need to install the corpus: **inaugural** in the same way as before.

# %% [markdown]
# ### Case Study: The inaugural speeches of the US Presidents
#
# #### Using nltk comprehensive list turn out to be useful

# %%
from nltk.corpus import udhr
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Downloading the inaugural speaches of US Presidents
from nltk.corpus import inaugural

# the First five speeches are
fileids = inaugural.fileids()
print(fileids[0:5])

# the year of the speech is always in the begining of the text
# The firts for digits can be retrieved using a comprehensive list
print([fileid[:4] for fileid in inaugural.fileids()][0:5])

# How many times is the word "war"  and "america" used ?
# group the outcome into a list "collection"
collection = [(target,fileid[:4]) for fileid in inaugural.fileids() 
 for w in inaugural.words(fileid) 
 for target in ['war', 'america'] if w.lower().startswith(target)]
collection[-1-20:-1]
# Out:
# ['1789-Washington.txt', '1793-Washington.txt', '1797-Adams.txt', '1801-Jefferson.txt', '1805-Jefferson.txt']
# ['1789', '1793', '1797', '1801', '1805']
# [('america', '2005'),
#  ('america', '2005'),
#  ('america', '2005'),
#  ('america', '2009'),
#  ('america', '2009'),
#  ('america', '2009'),
#  ('war', '2009'),
#  ('america', '2009'),
#  ('america', '2009'),
#  ('america', '2009'),
#  ('america', '2009'),
#  ('america', '2009'),
#  ('war', '2009'),
#  ('war', '2009'),
#  ('america', '2009'),
#  ('america', '2009'),
#  ('america', '2009'),
#  ('america', '2009'),
#  ('america', '2009'),
#  ('america', '2009')]

# %% [markdown]
# ### Evolution of the words war and america
#
# This can be visualised in a graph:

# %%
cfd = nltk.ConditionalFreqDist(collection)
fig  = plt.figure(figsize=(15,8))
cfd.plot();

# %% [markdown]
# ### Which language has the longuest words ?
#
# For this part of the notebook it is necessary to download udhr components. For that we can run the following in a terminal:
#
# * `import nltk`
# * `nltk.download('udhr')`

# %% [markdown]
# #### PDF of lenght of words

# %%
languages = ['Arabic_Alarabia-Arabic', 
             'English-Latin1', 
             'Farsi_Persian-UTF8',
             'Greenlandic_Inuktikut-Latin1', 
             'Hungarian_Magyar-Latin1', 
             'Dutch_Nederlands-Latin1']
fig , ax = plt.subplots(1,1,figsize=(15,8))
cfd = nltk.ConditionalFreqDist(
    (lang, len(word))
     for lang in languages
    for word in udhr.words(lang) )
ax.set_title('Pdf of the length of words',fontsize=14)
cfd.plot(cumulative=False);

# %% [markdown]
# #### Compleity of a laguage

# %%
fig , ax = plt.subplots(1,1,figsize=(15,8))
ax.set_title('Complexity of a language')
cfd.plot(cumulative=True);
