# %% [markdown]
# # NLP: TextBlob
# ## Displaying a wordcloud

# %% [markdown]
# ### 1. Make the necessary imports

# %%
from textblob import *

# %% [markdown]
# ### 2. Define the text of interest
# From the text below, a <b>word cloud </b>can be made

# %%
text_snippet="Running Deutsche Bank is ultimately a political job \
with a lot of reputational risk if anything goes wrong. A German solution\
like a merger with Commerzbank AG offers one way out. But it's hard to \
see how it could ever be presented as a merger of equals given the job \
losses that would probably be required. With Deutsche shares trading \
at a steeper discount to book value than Commerzbank, who exactly would \
end up being in charge? Budding CEOs-in-waiting will likely be bearing this in mind."

# %% [markdown]
# #### Use Textbloob to inspect the fist nouns

# %%
blob = TextBlob(text_snippet)
word_list = []
for p in blob.tags:
    if p[1]=='NN':
        word_list.append(p[0])

# %%
print('The first 5 words found:',word_list[0:5])
# Out:
# The first 5 words found: ['job', 'lot', 'risk', 'anything', 'solutionlike']

# %% [markdown]
# <hr>
# The wordcloud module can be installed via
# <ul>
# <li><b>pip install</b><br>
#     <i>pip install wordcloud</i>
#     This will require having a C compiler set up on your computer
#     <br>
#     <br>
# <li><b>conda install</b> using conda, you can install from the conda-forge channel:<br>
#     <i>conda install -c conda-forge wordcloud</i>
# </ul>

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 3. Getting Rid of stop words
#
# Stopwords are the English words which does not add much meaning to a sentence. They can safely be ignored without sacrificing the meaning of the sentence. For example, the words like the, he, have etc. Such words are already captured this in corpus named corpus.

# %%
# We can get a list of stop words directly from the module wordcloud
stopwords = set(STOPWORDS)

# %% [markdown]
# ### 4. Plotting the word cloud

# %%
wordcloud = WordCloud(background_color='white',
                      stopwords=stopwords,
                      max_words=30,
                      max_font_size=40,
                      random_state=42).generate(str(text_snippet))

# %%
fig = plt.figure(1,figsize=(10,10))
plt.imshow(wordcloud)
plt.axis('off');
